# %%
import numpy as np
import time as T
from joblib import Parallel, delayed
from scipy.interpolate import griddata,interpn,RegularGridInterpolator
import math
import os
import datetime
import rioxarray
import xarray as xr
import multiprocessing
import subprocess


# site_name = 'ROI 3'
# site = [27,96.5] # ROI 3

# site_name = 'ROI 6'
# site = [46,114]

# site_name = 'ROI 7'
# site = [35.328,99.052]

site_name = 'ROI 8'
site = [42.990,107.043]

# site_name = 'ROI 9'
# site = [41.7,104.6]

# site_name = 'ROI 10'
# site = [49.6,119.4]

d_ahi = []
with open("/home/liwei/Himawari_SGLI/{}_2020_PL.txt".format(site_name), "r") as f:
    for line in f.readlines():
        line = line.strip('\n') 
        if line[0:8] == 'AHI TIME':
            ahi = [line[9:13],line[14:16],line[17:19],line[20:22],line[23:25]]
            
            d_ahi.append("".join(ahi))
with open("/home/liwei/Himawari_SGLI/{}_2021_PL.txt".format(site_name), "r") as f:
    for line in f.readlines():
        line = line.strip('\n') 
        if line[0:8] == 'AHI TIME':
            ahi = [line[9:13],line[14:16],line[17:19],line[20:22],line[23:25]]
            
            d_ahi.append("".join(ahi))
            
target = '/media/liwei/Data/AHI_AC_RESULT_Validation/'
def mkdir(path):
    folder = os.path.exists(path) 
    if not folder:
        os.makedirs(path)

# %%
# Radiance

res = 0.01

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06



row_AHI = round((u_lat - d_lat) / res)
col_AHI = round((r_lon - l_lon) / res)

row_u_AHI = round((60 - u_lat)/res)
col_l_AHI = round((l_lon - 85)/res)

def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/Count2Radiance/vis.03')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.vis.03.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(12000,12000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + row_AHI , col_l_AHI:col_l_AHI + col_AHI]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b04_rad.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202008040430
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 20>()
#      31 folder_original = target+date+'_original/'
#      32 folder_AC = target+date+'_AC/'
# ---> 33 mkdir(folder_original)
#      34 mkdir(folder_AC)
#      35 # Download AHI
#
# Input In [8], in mkdir(path)
#      36 def mkdir(path):
# ---> 37     folder = os.path.exists(path)
#      38     if not folder:
#      39         os.makedirs(path)
#
# NameError: name 'os' is not defined

# %%
# Radiance

res = 0.005

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06


row_AHI = int((u_lat - d_lat) / res)
col_AHI = int((r_lon - l_lon) / res)

row_u_AHI = int((60 - u_lat)/res)
col_l_AHI = int((l_lon - 85)/res)




def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/Count2Radiance/ext.01')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.ext.01.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(24000,24000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + 24 , col_l_AHI:col_l_AHI + 24]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b03_rad.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202007140330
# time: 3.8 secs, 0.1 mins,0.0 hours
# start processing 202007290330
# time: 4.2 secs, 0.1 mins,0.0 hours
# start processing 202008020330
# time: 3.3 secs, 0.1 mins,0.0 hours
# start processing 202008130330
# time: 6.2 secs, 0.1 mins,0.0 hours
# start processing 202008170330
# time: 3.5 secs, 0.1 mins,0.0 hours
# start processing 202008210330
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202008250330
# time: 3.9 secs, 0.1 mins,0.0 hours
# start processing 202009050330
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202009090330
# time: 3.9 secs, 0.1 mins,0.0 hours
# start processing 202009280330
# time: 4.5 secs, 0.1 mins,0.0 hours
# start processing 202101230330
# time: 3.8 secs, 0.1 mins,0.0 hours
# start processing 202102070330
# time: 4.3 secs, 0.1 mins,0.0 hours
# start processing 202102220330
# time: 3.8 secs, 0.1 mins,0.0 hours
# start processing 202102260330
# time: 4.2 secs, 0.1 mins,0.0 hours
# start processing 202103130330
# time: 4.0 secs, 0.1 mins,0.0 hours
# start processing 202103280330
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202104010330
# time: 3.9 secs, 0.1 mins,0.0 hours
# start processing 202104160330
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202105010330
# time: 3.9 secs, 0.1 mins,0.0 hours
# start processing 202105050330
# time: 4.4 secs, 0.1 mins,0.0 hours

# %%
# Reflectance

res = 0.01

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06



row_AHI = round((u_lat - d_lat) / res)
col_AHI = round((r_lon - l_lon) / res)

row_u_AHI = round((60 - u_lat)/res)
col_l_AHI = round((l_lon - 85)/res)

def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/count2tbb_v102/vis.03')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.vis.03.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(12000,12000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + row_AHI , col_l_AHI:col_l_AHI + col_AHI]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b04_toa.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202007020410
# time: 1.2 secs, 0.0 mins,0.0 hours
# start processing 202007130420
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202007170410
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202007210410
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202008010410
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202008050410
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202008160350
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202008200400
# time: 0.7 secs, 0.0 mins,0.0 hours
# start processing 202008240400
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202009080340
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202102250350
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202103120340
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202103160330
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202103270340
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202103310400
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202104150400
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202104300350
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202105040400
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202105150400
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202105190400
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202106030400
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202106070410
# time: 0.7 secs, 0.0 mins,0.0 hours
# start processing 202106180410
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202106220410
# time: 0.8 secs, 0.0 mins,0.0 hours

# %%
# Radiance

res = 0.005

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06


row_AHI = int((u_lat - d_lat) / res)
col_AHI = int((r_lon - l_lon) / res)

row_u_AHI = int((60 - u_lat)/res)
col_l_AHI = int((l_lon - 85)/res)




def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/count2tbb_v102/ext.01')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.ext.01.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(24000,24000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + 24 , col_l_AHI:col_l_AHI + 24]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b03_toa.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202007020410
# time: 5.4 secs, 0.1 mins,0.0 hours
# start processing 202007130420
# time: 4.2 secs, 0.1 mins,0.0 hours
# start processing 202007170410
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202007210410
# time: 6.7 secs, 0.1 mins,0.0 hours
# start processing 202008010410
# time: 4.4 secs, 0.1 mins,0.0 hours
# start processing 202008050410
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202008160350
# time: 4.1 secs, 0.1 mins,0.0 hours
# start processing 202008200400
# time: 5.8 secs, 0.1 mins,0.0 hours
# start processing 202008240400
# time: 4.1 secs, 0.1 mins,0.0 hours
# start processing 202009080340
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202102250350
# time: 4.3 secs, 0.1 mins,0.0 hours
# start processing 202103120340
# time: 5.8 secs, 0.1 mins,0.0 hours
# start processing 202103160330
# time: 4.4 secs, 0.1 mins,0.0 hours
# start processing 202103270340
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202103310400
# time: 4.3 secs, 0.1 mins,0.0 hours
# start processing 202104150400
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202104300350
# time: 4.0 secs, 0.1 mins,0.0 hours
# start processing 202105040400
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202105150400
# time: 3.9 secs, 0.1 mins,0.0 hours
# start processing 202105190400
# time: 5.4 secs, 0.1 mins,0.0 hours
# start processing 202106030400
# time: 4.2 secs, 0.1 mins,0.0 hours
# start processing 202106070410
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202106180410
# time: 4.0 secs, 0.1 mins,0.0 hours
# start processing 202106220410
# time: 5.6 secs, 0.1 mins,0.0 hours
